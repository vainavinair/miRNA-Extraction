# %%
import pandas as pd
import requests
import os
from tqdm.notebook import tqdm
import math
from requests.exceptions import Timeout
import concurrent.futures
import threading
from concurrent.futures import ThreadPoolExecutor
import time
from typing import List, Tuple, Dict

# %%
# Global lock for file operations
file_lock = threading.Lock()

def download_single_file(mirna: str, download_dir: str, timeout: int = 30) -> Tuple[str, bool, str]:
    """Download a single miRNA file with better error handling"""
    try:
        print("Tring to download on: ",mirna,"\n")
        url = f'https://rnasysu.com/encori/moduleDownload.php?source=agoClipRNA&type=xls&value=hg38;lncRNA;{mirna};1;0;0;1;None;all'
        
        # Add retry mechanism
        max_retries = 3
        for attempt in range(max_retries):
            try:
                response = requests.get(url, timeout=timeout)
                response.raise_for_status()
                break
            except (requests.exceptions.RequestException, Timeout) as e:
                if attempt == max_retries - 1:
                    raise e
                time.sleep(2 ** attempt)  # Exponential backoff
        
        filename = f"{mirna.replace('/', '_')}.xls"
        file_path = os.path.join(download_dir, filename)
        
        with file_lock:
            with open(file_path, 'wb') as f:
                f.write(response.content)
        
        return filename, True, ""
        
    except Exception as e:
        return mirna, False, str(e)

# %%
# Modified read_file function from test-new.ipynb (cell 2)
def read_file(file_path: str) -> Tuple[pd.DataFrame, bool]:
    """Optimized file reading with manual content checking"""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            
        if "No Available results." in content:
            return pd.DataFrame(), True
            
        # Manual processing from test-new.ipynb
        lines = [line.strip() for line in content.split('\n') if line.strip()]
        data_lines = [line for line in lines if not line.startswith('#')]
        
        if not data_lines:
            return pd.DataFrame(), False
        
        processed_data = []
        for line in data_lines:
            row = [col.strip() for col in line.split('\t') if col.strip()]
            if row:
                processed_data.append(row)
        
        if processed_data:
            max_cols = max(len(row) for row in processed_data)
            padded_data = [row + [''] * (max_cols - len(row)) for row in processed_data]
            df = pd.DataFrame(
                padded_data[1:], 
                columns=padded_data[0] if padded_data else [f'Column_{i}' for i in range(max_cols)]
            )
            return df, False
            
        return pd.DataFrame(), False
        
    except Exception as e:
        raise Exception(f"Error reading file {file_path}: {str(e)}")

# Modified process_single_file logic from test-new.ipynb (cell 2)
def process_batch_parallel(files_batch: List[str], download_dir: str, max_workers: int = 4) -> Tuple[pd.DataFrame, List[str], List[str]]:
    """Process files in parallel using ThreadPoolExecutor"""
    no_results_files = []
    error_files = []
    processed_data = []
    
    def process_single_file(filename: str) -> Tuple[pd.DataFrame, str, bool]:
        try:
            print("Processing: ",filename,"\n")
            file_path = os.path.join(download_dir, filename)
            df, is_no_results = read_file(file_path)
            
            with file_lock:
                os.remove(file_path)
                
            if is_no_results:
                return pd.DataFrame(), filename, True
            
            # Modified extraction logic from test-new.ipynb
            if not df.empty and 'miRNAname' in df.columns and 'geneName' in df.columns and 'geneType' in df.columns:
                lncrna_rows = df[df['geneType'] == "lncRNA"]
                if not lncrna_rows.empty:
                    temp_df = lncrna_rows[['miRNAname', 'geneName']]
                    temp_df.columns = ['Column_B', 'Column_D']
                    return temp_df, filename, False
            
            return pd.DataFrame(), filename, False
            
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
            return pd.DataFrame(), filename, False
    
    # Rest of the original threading logic remains the same
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_single_file, filename) for filename in files_batch]
        
        for future in concurrent.futures.as_completed(futures):
            df, filename, is_no_results = future.result()
            
            if is_no_results:
                no_results_files.append(filename)
            elif not df.empty:  # Explicit empty check
                processed_data.append(df)
            else:
                error_files.append(filename)
    
    if processed_data:
        final_df = pd.concat(processed_data, ignore_index=True)
        return final_df, no_results_files, error_files
    
    return pd.DataFrame(columns=['Column_B', 'Column_D']), no_results_files, error_files

# %%
def download_batch(mirnas: List[str], download_dir: str, max_workers: int = 8) -> Tuple[List[str], List[str], List[str]]:
    """Download a batch of miRNAs in parallel"""
    downloaded_files = []
    not_downloaded = []
    errors = []
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_mirna = {executor.submit(download_single_file, mirna, download_dir): mirna for mirna in mirnas}
        
        for future in concurrent.futures.as_completed(future_to_mirna):
            filename, success, error = future.result()
            if success:
                downloaded_files.append(filename)
            else:
                not_downloaded.append(filename)
                if error:
                    errors.append(f"{filename}: {error}")
    
    return downloaded_files, not_downloaded, errors

def save_batch_results(batch_num: int, results: Dict) -> None:
    """Save batch results with error handling"""
    os.makedirs('output', exist_ok=True)
    try:
        for result_type, data in results.items():
            # Check if data is empty based on its type
            if isinstance(data, pd.DataFrame):
                if data.empty:
                    continue  # Skip empty DataFrame
            else:
                if not data:
                    continue  # Skip empty list
            
            filename = f'output/{result_type}_batch_{batch_num}.csv'
            if isinstance(data, pd.DataFrame):
                data.to_csv(filename, index=False)
            else:
                pd.DataFrame({'Filename': data}).to_csv(filename, index=False)
                
    except Exception as e:
        print(f"Error saving batch {batch_num} results: {str(e)}")

# %%
def download_and_process_mirna(excel_path: str, batch_size: int = 50, download_workers: int = 8, process_workers: int = 4) -> Tuple[int, int, int, int]:
    """Optimized main function with parallel processing"""
    # Read input file efficiently
    df = pd.read_excel(excel_path, usecols=['miRNA'])
    miRNAs = df['miRNA'].dropna().unique()
    
    # Create directories
    for dir_name in ['downloaded_files', 'output']:
        os.makedirs(dir_name, exist_ok=True)
    
    # Process in batches with progress tracking
    num_batches = math.ceil(len(miRNAs) / batch_size)
    all_results = {
        'data_not_found': [],
        'not_downloaded': [],
        'error_files': [],
        'extracted_data': []
    }
    
    with tqdm(total=num_batches, desc='Processing batches') as pbar:
        for batch_num in range(num_batches):
            start_idx = batch_num * batch_size
            end_idx = min((batch_num + 1) * batch_size, len(miRNAs))
            batch_miRNAs = miRNAs[start_idx:end_idx]
            
            # Download batch in parallel
            downloaded_files, not_downloaded, errors = download_batch(
                batch_miRNAs,
                'downloaded_files',
                max_workers=download_workers
            )
            
            # Process downloaded files in parallel
            extracted_data, no_results, process_errors = process_batch_parallel(
                downloaded_files,
                'downloaded_files',
                max_workers=process_workers
            )
            
            # Save batch results
            batch_results = {
                'data_not_found': no_results,
                'not_downloaded': not_downloaded,
                'error_files': errors + process_errors,
                'extracted_data': extracted_data
            }
            save_batch_results(batch_num + 1, batch_results)
            
            # Accumulate results
            for key in all_results:
                if key == 'extracted_data':
                    if not extracted_data.empty:
                        all_results[key].append(extracted_data)
                else:
                    all_results[key].extend(batch_results[key])
            
            pbar.update(1)
    
    # Combine and save final results
    if all_results['extracted_data']:
        final_data = pd.concat(all_results['extracted_data'], ignore_index=True)
        final_data.to_csv('output/extracted_data_final.csv', index=False)
    
    for key in ['data_not_found', 'not_downloaded', 'error_files']:
        if all_results[key]:
            pd.DataFrame({'Filename': all_results[key]}).to_csv(f'output/{key}_final.csv', index=False)
    
    # Clean up download directory
    if os.path.exists('downloaded_files') and not os.listdir('downloaded_files'):
        os.rmdir('downloaded_files')
    
    return (
        len(all_results['data_not_found']),
        len(final_data) if 'final_data' in locals() else 0,
        len(all_results['error_files']),
        len(all_results['not_downloaded'])
    )

# %%
no_results_count, extracted_rows, error_count, not_downloaded_count = download_and_process_mirna(
    'get_id.xlsx',
    batch_size=50,
    download_workers=8,  
    process_workers=4    
)
print(f"\nProcessing complete!")
print(f"Files with no results: {no_results_count}")
print(f"Files with errors: {error_count}")
print(f"Files not downloaded (timeout): {not_downloaded_count}")
print(f"Total rows extracted: {extracted_rows}")
# Out:
# Processing batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Tring to download on:  hsa-miR-876-5p
#
# Tring to download on:  hsa-miR-3167
#
# Tring to download on:  hsa-miR-2276-3p
#
# Tring to download on:  hsa-miR-5003-5p
#
# Tring to download on:  hsa-miR-7112-3p
#
# Tring to download on:  hsa-miR-3156-3p
#
# Tring to download on:  hsa-miR-3974
#
# Tring to download on:  hsa-miR-5691
#
# Tring to download on:  hsa-miR-6805-3p
#
# Tring to download on:  hsa-miR-6080
#
# Tring to download on:  hsa-miR-6890-3p
#
# Tring to download on:  hsa-miR-676-3p
#
# Tring to download on:  hsa-miR-5009-3p
#
# Tring to download on:  hsa-miR-4307
#
# Tring to download on:  hsa-miR-450b-3p
#
# Tring to download on:  hsa-miR-4769-3p
#
# Tring to download on:  hsa-miR-6817-5p
#
# Tring to download on:  hsa-miR-4765
#
# Tring to download on:  hsa-miR-6751-5p
#
# Tring to download on:  hsa-miR-6752-5p
#
# Tring to download on:  hsa-miR-6777-5p
#
# Tring to download on:  hsa-miR-6803-5p
#
# Tring to download on:  hsa-miR-6835-5p
#
# Tring to download on:  hsa-miR-6842-5p
#
# Tring to download on:  hsa-miR-6889-5p
#
# Tring to download on:  hsa-miR-7110-5p
#
# Tring to download on:  hsa-miR-7844-5p
#
# Tring to download on:  hsa-miR-4330
#
# Tring to download on:  hsa-miR-4793-3p
#
# Tring to download on:  hsa-miR-6715a-3p
#
# Tring to download on:  hsa-miR-3152-5p
#
# Tring to download on:  hsa-miR-520a-5p
#
# Tring to download on:  hsa-miR-525-5p
#
# Tring to download on:  hsa-miR-1207-3p
#
# Tring to download on:  hsa-miR-3135a
#
# Tring to download on:  hsa-miR-497-3p
#
# Tring to download on:  hsa-miR-3934-3p
#
# Tring to download on:  hsa-miR-6854-5p
#
# Tring to download on:  hsa-miR-3913-3p
#
# Tring to download on:  hsa-miR-4276
#
# Tring to download on:  hsa-miR-3942-3p
#
# Tring to download on:  hsa-miR-4469
#
# Tring to download on:  hsa-miR-7977
#
# Tring to download on:  hsa-miR-5701
#
# Tring to download on:  hsa-miR-223-5p
#
# Tring to download on:  hsa-miR-3670
#
# Tring to download on:  hsa-miR-4789-3p
#
# Tring to download on:  hsa-miR-6841-3p
#
# Tring to download on:  hsa-miR-96-3p
#
# Tring to download on:  hsa-miR-2681-3p
#
# Processing:  hsa-miR-5003-5p.xls
#
# Processing:  hsa-miR-7112-3p.xls
#
# Processing:  hsa-miR-3167.xls
#
# Processing:  hsa-miR-2276-3p.xls
#
# Processing:  hsa-miR-3156-3p.xls
#
# Processing:  hsa-miR-3974.xls
#
# Processing:  hsa-miR-5691.xls
#
# Processing:  hsa-miR-6805-3p.xls
#
# Processing:  hsa-miR-6890-3p.xls
#
# Processing:  hsa-miR-6080.xls
#
# Processing:  hsa-miR-676-3p.xls
#
# Processing:  hsa-miR-4307.xls
#
# Processing:  hsa-miR-5009-3p.xls
#
# Processing:  hsa-miR-450b-3p.xls
#
# Processing:  hsa-miR-4769-3p.xls
#
# Processing:  hsa-miR-6817-5p.xls
#
# Processing:  hsa-miR-4765.xls
#
# Processing:  hsa-miR-6751-5p.xls
#
# Processing:  hsa-miR-6777-5p.xls
#
# Processing:  hsa-miR-6752-5p.xls
#
# Processing:  hsa-miR-6803-5p.xls
#
# Processing:  hsa-miR-6835-5p.xls
#
# Processing:  hsa-miR-6842-5p.xls
#
# Processing:  hsa-miR-7110-5p.xls
#
# Processing:  hsa-miR-7844-5p.xls
#
# Processing:  hsa-miR-6889-5p.xls
#
# Processing:  hsa-miR-4330.xls
#
# Processing:  hsa-miR-4793-3p.xls
#
# Processing:  hsa-miR-876-5p.xls
#
# Processing:  hsa-miR-6715a-3p.xls
#
# Processing:  hsa-miR-3152-5p.xls
#
# Processing:  hsa-miR-520a-5p.xls
#
# Processing:  hsa-miR-497-3p.xls
#
# Processing:  hsa-miR-3135a.xls
#
# Processing:  hsa-miR-1207-3p.xls
#
# Processing:  hsa-miR-3934-3p.xls
#
# Processing:  hsa-miR-6854-5p.xls
#
# Processing:  hsa-miR-3913-3p.xls
#
# Processing:  hsa-miR-4276.xls
#
# Processing:  hsa-miR-7977.xls
#
# Processing:  hsa-miR-3942-3p.xls
#
# Processing:  hsa-miR-5701.xls
#
# Processing:  hsa-miR-223-5p.xls
#
# Processing:  hsa-miR-4789-3p.xls
#
# Processing:  hsa-miR-3670.xls
#
# Processing:  hsa-miR-6841-3p.xls
#
# Processing:  hsa-miR-2681-3p.xls
#
# Processing:  hsa-miR-4469.xls
#
# Processing:  hsa-miR-96-3p.xls
#
# Processing:  hsa-miR-525-5p.xls
#
# Tring to download on:  hsa-miR-4708-5p
#
# Tring to download on:  hsa-miR-4712-3p
#
# Tring to download on:  hsa-miR-6516-3p
#
# Tring to download on:  hsa-miR-4804-3p
#
# Tring to download on:  hsa-miR-4637
#
# Tring to download on:  hsa-miR-4659a-5p
#
# Tring to download on:  hsa-miR-4661-3p
#
# Tring to download on:  hsa-miR-4659b-5p
#
# Tring to download on:  hsa-miR-4802-5p
#
# Tring to download on:  hsa-miR-6894-5p
#
# Tring to download on:  hsa-miR-7154-3p
#
# Tring to download on:  hsa-miR-5683
#
# Tring to download on:  hsa-miR-5690
#
# Tring to download on:  hsa-miR-3978
#
# Tring to download on:  hsa-miR-5093
#
# Tring to download on:  hsa-miR-8069
#
# Tring to download on:  hsa-miR-8075
#
# Tring to download on:  hsa-miR-3926
#
# Tring to download on:  hsa-miR-7154-5p
#
# Tring to download on:  hsa-miR-5681b
#
# Tring to download on:  hsa-miR-1261
#
# Tring to download on:  hsa-miR-8081
#
# Tring to download on:  hsa-miR-3120-5p
#
# Tring to download on:  hsa-miR-4743-3p
#
# Tring to download on:  hsa-miR-6807-3p
#
# Tring to download on:  hsa-miR-4468
#
# Tring to download on:  hsa-miR-640
#
# Tring to download on:  hsa-miR-4753-3p
#
# Tring to download on:  hsa-miR-556-3p
#
# Tring to download on:  hsa-miR-4457
#
# Tring to download on:  hsa-miR-302f
#
# Tring to download on:  hsa-miR-487a-5p
#
# Tring to download on:  hsa-miR-487b-5p
#
# Tring to download on:  hsa-miR-4790-3p
#
# Tring to download on:  hsa-miR-205-3p
#
# Tring to download on:  hsa-miR-6830-5p
#
# Tring to download on:  hsa-miR-4646-3p
#
# Tring to download on:  hsa-miR-1233-5p
#
# Tring to download on:  hsa-miR-6778-5p
#
# Tring to download on:  hsa-miR-4722-3p
#
# Tring to download on:  hsa-miR-6727-3p
#
# Tring to download on:  hsa-miR-4704-5p
#
# Tring to download on:  hsa-miR-6868-5p
#
# Tring to download on:  hsa-miR-4687-5p
#
# Tring to download on:  hsa-miR-6779-3p
#
# Tring to download on:  hsa-miR-6853-5p
#
# Tring to download on:  hsa-miR-4475
#
# Tring to download on:  hsa-miR-6775-3p
#
# Tring to download on:  hsa-miR-3918
#
# Tring to download on:  hsa-miR-4640-5p
#
# Processing:  hsa-miR-6516-3p.xls
#
# Processing:  hsa-miR-4659b-5p.xls
#
# Processing:  hsa-miR-4708-5p.xls
#
# Processing:  hsa-miR-4659a-5p.xls
#
# Processing:  hsa-miR-4637.xls
#
# Processing:  hsa-miR-4802-5p.xls
#
# Processing:  hsa-miR-6894-5p.xls
#
# Processing:  hsa-miR-7154-3p.xls
#
# Processing:  hsa-miR-5690.xls
#
# Processing:  hsa-miR-3978.xls
#
# Processing:  hsa-miR-5683.xls
#
# Processing:  hsa-miR-5093.xls
#
# Processing:  hsa-miR-8069.xls
#
# Processing:  hsa-miR-8075.xls
#
# Processing:  hsa-miR-4804-3p.xls
#
# Processing:  hsa-miR-7154-5p.xls
#
# Processing:  hsa-miR-5681b.xls
#
# Processing:  hsa-miR-8081.xls
#
# Processing:  hsa-miR-4743-3p.xls
#
# Processing:  hsa-miR-6807-3p.xls
#
# Processing:  hsa-miR-4468.xls
#
# Processing:  hsa-miR-3120-5p.xls
#
# Processing:  hsa-miR-640.xls
#
# Processing:  hsa-miR-556-3p.xls
#
# Processing:  hsa-miR-4753-3p.xls
#
# Processing:  hsa-miR-4457.xls
#
# Processing:  hsa-miR-302f.xls
#
# Processing:  hsa-miR-487a-5p.xls
#
# Processing:  hsa-miR-487b-5p.xls
#
# Processing:  hsa-miR-4790-3p.xls
#
# Processing:  hsa-miR-205-3p.xls
#
# Processing:  hsa-miR-4646-3p.xls
#
# Processing:  hsa-miR-1233-5p.xls
#
# Processing:  hsa-miR-4722-3p.xls
#
# Processing:  hsa-miR-6830-5p.xls
#
# Processing:  hsa-miR-6727-3p.xls
#
# Processing:  hsa-miR-4704-5p.xls
#
# Processing:  hsa-miR-4712-3p.xls
#
# Processing:  hsa-miR-6868-5p.xls
#
# Processing:  hsa-miR-6779-3p.xls
#
# Processing:  hsa-miR-4687-5p.xls
#
# Processing:  hsa-miR-4475.xls
#
# Processing:  hsa-miR-6775-3p.xls
#
# Processing:  hsa-miR-3918.xls
#
# Processing:  hsa-miR-6778-5p.xls
#
# Processing:  hsa-miR-4640-5p.xls
#
# Processing:  hsa-miR-4661-3p.xls
#
# Processing:  hsa-miR-6853-5p.xls
#
# Processing:  hsa-miR-3926.xls
#
# Processing:  hsa-miR-1261.xls
#
# Tring to download on:  hsa-miR-4726-5p
#
# Tring to download on:  hsa-miR-6501-3p
#
# Tring to download on:  hsa-miR-6895-5p
#
# Tring to download on:  hsa-miR-8057
#
# Tring to download on:  hsa-miR-4445-3p
#
# Tring to download on:  hsa-miR-548al
#
# Tring to download on:  hsa-miR-6507-3p
#
# Tring to download on:  hsa-miR-6499-3p
#
# Tring to download on:  hsa-miR-6815-5p
#
# Tring to download on:  hsa-miR-6865-5p
#
# Tring to download on:  hsa-miR-323b-3p
#
# Tring to download on:  hsa-miR-4434
#
# Tring to download on:  hsa-miR-5703
#
# Tring to download on:  hsa-miR-4481
#
# Tring to download on:  hsa-miR-4745-5p
#
# Tring to download on:  hsa-miR-598-5p
#
# Tring to download on:  hsa-miR-3688-3p
#
# Tring to download on:  hsa-miR-891b
#
# Tring to download on:  hsa-miR-5585-5p
#
# Tring to download on:  hsa-miR-6888-5p
#
# Tring to download on:  hsa-miR-3179
#
# Tring to download on:  hsa-miR-4639-3p
#
# Tring to download on:  hsa-miR-6810-5p
#
# Tring to download on:  hsa-miR-1255a
#
# Tring to download on:  hsa-miR-1255b-5p
#
# Tring to download on:  hsa-miR-4700-3p
#
# Tring to download on:  hsa-miR-4740-5p
#
# Tring to download on:  hsa-miR-539-3p
#
# Tring to download on:  hsa-miR-4688
#
# Tring to download on:  hsa-miR-6743-5p
#
# Tring to download on:  hsa-miR-6789-5p
#
# Tring to download on:  hsa-miR-5004-3p
#
# Tring to download on:  hsa-miR-6514-5p
#
# Tring to download on:  hsa-miR-1537-5p
#
# Tring to download on:  hsa-miR-4308
#
# Tring to download on:  hsa-miR-4292
#
# Tring to download on:  hsa-miR-4291
#
# Tring to download on:  hsa-miR-6791-5p
#
# Tring to download on:  hsa-miR-1-5p
#
# Tring to download on:  hsa-miR-4714-3p
#
# Tring to download on:  hsa-miR-1269a
#
# Tring to download on:  hsa-miR-1269b
#
# Tring to download on:  hsa-miR-4529-3p
#
# Tring to download on:  hsa-miR-4520-2-3p
#
# Tring to download on:  hsa-miR-5009-5p
#
# Tring to download on:  hsa-miR-7850-5p
#
# Tring to download on:  hsa-miR-8058
#
# Tring to download on:  hsa-miR-4494
#
# Tring to download on:  hsa-miR-499b-5p
#
# Tring to download on:  hsa-miR-493-5p
#
# Processing:  hsa-miR-548al.xls
#
# Processing:  hsa-miR-6895-5p.xls
#
# Processing:  hsa-miR-4445-3p.xls
#
# Processing:  hsa-miR-6507-3p.xls
#
# Processing:  hsa-miR-6501-3p.xls
#
# Processing:  hsa-miR-4726-5p.xls
#
# Processing:  hsa-miR-8057.xls
#
# Processing:  hsa-miR-6499-3p.xls
#
# Processing:  hsa-miR-6865-5p.xls
#
# Processing:  hsa-miR-5703.xls
#
# Processing:  hsa-miR-323b-3p.xls
#
# Processing:  hsa-miR-4481.xls
#
# Processing:  hsa-miR-4434.xls
#
# Processing:  hsa-miR-598-5p.xls
#
# Processing:  hsa-miR-4745-5p.xls
#
# Processing:  hsa-miR-3688-3p.xls
#
# Processing:  hsa-miR-6888-5p.xls
#
# Processing:  hsa-miR-5585-5p.xls
#
# Processing:  hsa-miR-4639-3p.xls
#
# Processing:  hsa-miR-3179.xls
#
# Processing:  hsa-miR-6810-5p.xls
#
# Processing:  hsa-miR-1255a.xls
#
# Processing:  hsa-miR-4700-3p.xls
#
# Processing:  hsa-miR-4688.xls
#
# Processing:  hsa-miR-539-3p.xls
#
# Processing:  hsa-miR-4740-5p.xls
#
# Processing:  hsa-miR-6743-5p.xls
#
# Processing:  hsa-miR-6789-5p.xls
#
# Processing:  hsa-miR-5004-3p.xls
#
# Processing:  hsa-miR-6514-5p.xls
#
# Processing:  hsa-miR-4308.xls
#
# Processing:  hsa-miR-4292.xls
#
# Processing:  hsa-miR-4291.xls
#
# Processing:  hsa-miR-6791-5p.xls
#
# Processing:  hsa-miR-1-5p.xls
#
# Processing:  hsa-miR-4714-3p.xls
#
# Processing:  hsa-miR-1269a.xls
#
# Processing:  hsa-miR-1269b.xls
#
# Processing:  hsa-miR-5009-5p.xls
#
# Processing:  hsa-miR-4520-2-3p.xls
#
# Processing:  hsa-miR-7850-5p.xls
#
# Processing:  hsa-miR-4529-3p.xls
#
# Processing:  hsa-miR-8058.xls
#
# Processing:  hsa-miR-4494.xls
#
# Processing:  hsa-miR-499b-5p.xls
#
# Processing:  hsa-miR-493-5p.xls
#
# Processing:  hsa-miR-1255b-5p.xls
#
# Processing:  hsa-miR-1537-5p.xls
#
# Processing:  hsa-miR-6815-5p.xls
#
# Processing:  hsa-miR-891b.xls
#
# Tring to download on:  hsa-miR-6758-3p
#
# Tring to download on:  hsa-miR-627-5p
#
# Tring to download on:  hsa-miR-8055
#
# Tring to download on:  hsa-miR-4474-3p
#
# Tring to download on:  hsa-miR-3140-5p
#
# Tring to download on:  hsa-miR-3667-5p
#
# Tring to download on:  hsa-miR-4761-5p
#
# Tring to download on:  hsa-miR-6801-5p
#
# Tring to download on:  hsa-miR-3605-5p
#
# Tring to download on:  hsa-miR-363-5p
#
# Tring to download on:  hsa-miR-369-3p
#
# Tring to download on:  hsa-miR-323a-5p
#
# Tring to download on:  hsa-miR-4483
#
# Tring to download on:  hsa-miR-6745
#
# Tring to download on:  hsa-miR-8074
#
# Tring to download on:  hsa-miR-1238-5p
#
# Tring to download on:  hsa-miR-4658
#
# Tring to download on:  hsa-miR-4758-5p
#
# Tring to download on:  hsa-miR-6790-5p
#
# Tring to download on:  hsa-miR-100-3p
#
# Tring to download on:  hsa-miR-514b-5p
#
# Tring to download on:  hsa-miR-6741-3p
#
# Tring to download on:  hsa-miR-4783-3p
#
# Tring to download on:  hsa-miR-4774-3p
#
# Tring to download on:  hsa-miR-20b-3p
#
# Tring to download on:  hsa-miR-1343-3p
#
# Tring to download on:  hsa-miR-6783-3p
#
# Tring to download on:  hsa-miR-4662a-5p
#
# Tring to download on:  hsa-miR-3129-3p
#
# Tring to download on:  hsa-miR-5583-5p
#
# Tring to download on:  hsa-miR-4762-5p
#
# Tring to download on:  hsa-miR-1247-3p
#
# Tring to download on:  hsa-miR-1265
#
# Tring to download on:  hsa-miR-2355-3p
#
# Tring to download on:  hsa-miR-4776-3p
#
# Tring to download on:  hsa-miR-6837-3p
#
# Tring to download on:  hsa-miR-6868-3p
#
# Tring to download on:  hsa-miR-4433a-5p
#
# Tring to download on:  hsa-miR-4721
#
# Tring to download on:  hsa-miR-4653-3p
#
# Tring to download on:  hsa-miR-514a-5p
#
# Tring to download on:  hsa-miR-6861-5p
#
# Tring to download on:  hsa-miR-6757-5p
#
# Tring to download on:  hsa-miR-621
#
# Tring to download on:  hsa-miR-675-3p
#
# Tring to download on:  hsa-miR-3149
#
# Tring to download on:  hsa-miR-3672
#
# Tring to download on:  hsa-miR-6864-3p
#
# Tring to download on:  hsa-miR-6882-3p
#
# Tring to download on:  hsa-miR-4705
#
# Processing:  hsa-miR-3667-5p.xls
#
# Processing:  hsa-miR-627-5p.xls
#
# Processing:  hsa-miR-6801-5p.xls
#
# Processing:  hsa-miR-8055.xls
#
# Processing:  hsa-miR-4761-5p.xls
#
# Processing:  hsa-miR-3140-5p.xls
#
# Processing:  hsa-miR-6758-3p.xls
#
# Processing:  hsa-miR-363-5p.xls
#
# Processing:  hsa-miR-3605-5p.xls
#
# Processing:  hsa-miR-8074.xls
#
# Processing:  hsa-miR-4483.xls
#
# Processing:  hsa-miR-323a-5p.xls
#
# Processing:  hsa-miR-369-3p.xls
#
# Processing:  hsa-miR-6745.xls
#
# Processing:  hsa-miR-4474-3p.xls
#
# Processing:  hsa-miR-1238-5p.xls
#
# Processing:  hsa-miR-6790-5p.xls
#
# Processing:  hsa-miR-4658.xls
#
# Processing:  hsa-miR-4758-5p.xls
#
# Processing:  hsa-miR-100-3p.xls
#
# Processing:  hsa-miR-6741-3p.xls
#
# Processing:  hsa-miR-514b-5p.xls
#
# Processing:  hsa-miR-4783-3p.xls
#
# Processing:  hsa-miR-4774-3p.xls
#
# Processing:  hsa-miR-6783-3p.xls
#
# Processing:  hsa-miR-20b-3p.xls
#
# Processing:  hsa-miR-4662a-5p.xls
#
# Processing:  hsa-miR-1343-3p.xls
#
# Processing:  hsa-miR-5583-5p.xls
#
# Processing:  hsa-miR-4762-5p.xls
#
# Processing:  hsa-miR-1247-3p.xls
#
# Processing:  hsa-miR-4776-3p.xls
#
# Processing:  hsa-miR-6868-3p.xls
#
# Processing:  hsa-miR-6837-3p.xls
#
# Processing:  hsa-miR-2355-3p.xls
#
# Processing:  hsa-miR-4433a-5p.xls
#
# Processing:  hsa-miR-4721.xls
#
# Processing:  hsa-miR-514a-5p.xls
#
# Processing:  hsa-miR-4653-3p.xls
#
# Processing:  hsa-miR-6757-5p.xls
#
# Processing:  hsa-miR-6861-5p.xls
#
# Processing:  hsa-miR-621.xls
#
# Processing:  hsa-miR-1265.xls
#
# Processing:  hsa-miR-3149.xls
#
# Processing:  hsa-miR-3672.xls
#
# Processing:  hsa-miR-675-3p.xls
#
# Processing:  hsa-miR-6882-3p.xls
#
# Processing:  hsa-miR-4705.xls
#
# Processing:  hsa-miR-6864-3p.xls
#
# Processing:  hsa-miR-3129-3p.xls
#
# Tring to download on:  hsa-miR-587
#
# Processing:  hsa-miR-587.xls
#
#
# Processing complete!
# Files with no results: 168
# Files with errors: 0
# Files not downloaded (timeout): 0
# Total rows extracted: 1620
